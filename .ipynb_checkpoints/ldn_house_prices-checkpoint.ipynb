# %% [markdown]
# ## 1. Introduction <a id="1"></a>
#
# This notebook explores how the house prices in London have changed over the period of 1995 to 2020.
#
# ![london house](Pictures\london_houses.jpg)
#
# ### **Table of Contents**
# * [Introduction](#1)
# * [Data Processing](#2)
# * [Data Exploration](#3)
# * [House Prices Prediction](#4)

# %%
# Load libraries

import pandas as pd
import numpy as np

import missingno as msno
import statsmodels.api as sm

# from fbprophet import Prophet

import geopandas as gpd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from pylab import rcParams
rcParams['figure.figsize'] = 15, 12

# Allows to display all of the outputs of a cell
from IPython.display import display

# Set float data type format
pd.options.display.float_format = '{:,.2f}'.format

# Set the maximum number of row to be displayed
pd.options.display.max_rows = 999

# Set global visualisation settings
plt.rc('font', size=14)

# %%
df = pd.read_csv('housing_in_london_monthly_variables.csv')
df_1 = pd.read_csv('housing_in_london_yearly_variables.csv')

display(df.head())
display(df_1.head())
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001        17.00
# 1  1995-02-01  city of london          82203  E09000001         7.00
# 2  1995-03-01  city of london          79121  E09000001        14.00
# 3  1995-04-01  city of london          77101  E09000001         7.00
# 4  1995-05-01  city of london          84409  E09000001        10.00
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1
#         code                  area        date  median_salary  \
# 0  E09000001        city of london  1999-12-01      33,020.00
# 1  E09000002  barking and dagenham  1999-12-01      21,480.00
# 2  E09000003                barnet  1999-12-01      19,568.00
# 3  E09000004                bexley  1999-12-01      18,621.00
# 4  E09000005                 brent  1999-12-01      18,532.00
#
#    life_satisfaction mean_salary recycling_pct  population_size  \
# 0                NaN       48922             0         6,581.00
# 1                NaN       23620             3       162,444.00
# 2                NaN       23128             8       313,469.00
# 3                NaN       21386            18       217,458.00
# 4                NaN       20911             6       260,317.00
#
#    number_of_jobs  area_size  no_of_houses  borough_flag
# 0             NaN        NaN           NaN             1
# 1             NaN        NaN           NaN             1
# 2             NaN        NaN           NaN             1
# 3             NaN        NaN           NaN             1
# 4             NaN        NaN           NaN             1

# %% [markdown]
# ## 2. Data Processing <a id="2"></a>

# %%
display(df.describe());

msno.matrix(df);
# Out:
#        average_price  houses_sold  no_of_crimes  borough_flag
# count      13,549.00    13,455.00      7,439.00     13,549.00
# mean      263,519.68     3,893.99      2,158.35          0.73
# std       187,617.50    12,114.40        902.09          0.44
# min        40,722.00         2.00          0.00          0.00
# 25%       132,380.00       247.00      1,623.00          0.00
# 50%       222,919.00       371.00      2,132.00          1.00
# 75%       336,843.00     3,146.00      2,582.00          1.00
# max     1,463,378.00   132,163.00      7,461.00          1.00

# %% [markdown]
# Observations:
# * Yearly data is missing a few **'houses_sold'** values
# * Many values are missing for the **'no_of_crimes'** variable

# %%
display(df_1.describe())

msno.matrix(df_1);
# Out:
#        median_salary  life_satisfaction  population_size  number_of_jobs  \
# count       1,049.00             352.00         1,018.00          931.00
# mean       27,977.79               7.49     6,042,576.49    3,188,094.52
# std         6,412.81               0.20    15,268,096.56    8,058,302.24
# min        15,684.00               7.00         6,581.00       47,000.00
# 25%        23,857.00               7.35       224,345.75       94,500.00
# 50%        27,441.00               7.51       294,603.50      157,000.00
# 75%        30,932.00               7.64     4,630,098.50    2,217,000.00
# max        61,636.00               7.96    66,435,550.00   35,750,000.00
#
#           area_size  no_of_houses  borough_flag
# count        666.00        666.00      1,071.00
# mean     372,490.27    881,468.15          0.65
# std    2,157,060.24  3,690,376.14          0.48
# min          315.00      5,009.00          0.00
# 25%        2,960.00     87,635.50          0.00
# 50%        4,323.00    102,402.00          1.00
# 75%        8,220.00    126,276.00          1.00
# max   13,303,728.00 24,172,166.00          1.00

# %%
# Set date as index for easier manipulation
df = df.set_index(pd.to_datetime(df['date']))
df_1 = df_1.set_index(pd.to_datetime(df_1['date']))

del df['date']
del df_1['date']

df_1['mean_salary'] = df_1['mean_salary'].replace('-', np.NaN)
df_1['mean_salary'] = df_1['mean_salary'].replace('#', np.NaN)
df_1['mean_salary'] = df_1['mean_salary'].astype(float)

# Create dataset cuts
prices_london = df[df['borough_flag'] == 1]
prices_england = df[df['area'] == 'england']
prices_north_east = df[df['area'] == 'north east']

# Calcualte mean prices for the different cuts of data
london_mean_price = prices_london.groupby('date')['average_price'].mean()
england_mean_price = prices_england.groupby('date')['average_price'].mean()
north_east_mean_price = prices_north_east.groupby('date')['average_price'].mean()

print('Processing Complete')
# Out:
# Processing Complete

# %% [markdown]
# ## 3. Data Exploration <a id="3"></a>

# %% [markdown]
# ### 3.1 Main Variable Analysis

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=london_mean_price.index, 
                         y=london_mean_price.values,
                         mode='lines',
                         name='London Mean House Price',
                        ))

fig.add_trace(go.Scatter(x=england_mean_price.index, 
                         y=england_mean_price.values,
                         mode='lines',
                         name='England Mean House Price',
                        ))

fig.add_trace(go.Scatter(x=north_east_mean_price.index, 
                         y=north_east_mean_price.values,
                         mode='lines',
                         name='North East Mean House Price',
                        ))


fig.update_layout(
    template='gridon',
    title='Average Monthly House Price',
    xaxis_title='Year',
    yaxis_title='Price (£)',
    xaxis_showgrid=False,
    yaxis_showgrid=False,
    legend=dict(y=-.2, orientation='h'),
    shapes=[
        dict(
            type="line",
            x0='2016-06-01',
            x1='2016-06-01',
            y0=0,
            y1=london_mean_price.values.max()*1.2,
            line=dict(
            color="LightSalmon",
            dash="dashdot"
            )
        ),
        dict(
            type="rect",
            x0="2007-12-01",
            y0=0,
            x1="2009-06-01",
            y1=london_mean_price.values.max()*1.2,
            fillcolor="LightSalmon",
            opacity=0.5,
            layer="below",
            line_width=0,
        ),
        dict(
            type="rect",
            x0="2001-03-01",
            y0=0,
            x1="2001-11-01",
            y1=london_mean_price.values.max()*1.2,
            fillcolor="LightSalmon",
            opacity=0.5,
            layer="below",
            line_width=0,
        )
    ],
    annotations=[
            dict(text="The Great Recession", x='2007-12-01', y=london_mean_price.values.max()*1.2),
            dict(text="Brexit Vote", x='2016-06-01', y=london_mean_price.values.max()*1.2),
            dict(text="Dot-Com Bubble Recession", x='2001-03-01', y=london_mean_price.values.max()*1.2)
    ]
)

fig.show()
# Out:
# <div>                            <div id="55da6209-2d30-4011-93b3-534d8904b664" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55da6209-2d30-4011-93b3-534d8904b664")) {                    Plotly.newPlot(                        "55da6209-2d30-4011-93b3-534d8904b664",                        [{"mode":"lines","name":"London Mean House Price","x":["1995-01-01T00:00:00","1995-02-01T00:00:00","1995-03-01T00:00:00","1995-04-01T00:00:00","1995-05-01T00:00:00","1995-06-01T00:00:00","1995-07-01T00:00:00","1995-08-01T00:00:00","1995-09-01T00:00:00","1995-10-01T00:00:00","1995-11-01T00:00:00","1995-12-01T00:00:00","1996-01-01T00:00:00","1996-02-01T00:00:00","1996-03-01T00:00:00","1996-04-01T00:00:00","1996-05-01T00:00:00","1996-06-01T00:00:00","1996-07-01T00:00:00","1996-08-01T00:00:00","1996-09-01T00:00:00","1996-10-01T00:00:00","1996-11-01T00:00:00","1996-12-01T00:00:00","1997-01-01T00:00:00","1997-02-01T00:00:00","1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00","1998-05-01T00:00:00","1998-06-01T00:00:00","1998-07-01T00:00:00","1998-08-01T00:00:00","1998-09-01T00:00:00","1998-10-01T00:00:00","1998-11-01T00:00:00","1998-12-01T00:00:00","1999-01-01T00:00:00","1999-02-01T00:00:00","1999-03-01T00:00:00","1999-04-01T00:00:00","1999-05-01T00:00:00","1999-06-01T00:00:00","1999-07-01T00:00:00","1999-08-01T00:00:00","1999-09-01T00:00:00","1999-10-01T00:00:00","1999-11-01T00:00:00","1999-12-01T00:00:00","2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00:00:00","2001-02-01T00:00:00","2001-03-01T00:00:00","2001-04-01T00:00:00","2001-05-01T00:00:00","2001-06-01T00:00:00","2001-07-01T00:00:00","2001-08-01T00:00:00","2001-09-01T00:00:00","2001-10-01T00:00:00","2001-11-01T00:00:00","2001-12-01T00:00:00","2002-01-01T00:00:00","2002-02-01T00:00:00","2002-03-01T00:00:00","2002-04-01T00:00:00","2002-05-01T00:00:00","2002-06-01T00:00:00","2002-07-01T00:00:00","2002-08-01T00:00:00","2002-09-01T00:00:00","2002-10-01T00:00:00","2002-11-01T00:00:00","2002-12-01T00:00:00","2003-01-01T00:00:00","2003-02-01T00:00:00","2003-03-01T00:00:00","2003-04-01T00:00:00","2003-05-01T00:00:00","2003-06-01T00:00:00","2003-07-01T00:00:00","2003-08-01T00:00:00","2003-09-01T00:00:00","2003-10-01T00:00:00","2003-11-01T00:00:00","2003-12-01T00:00:00","2004-01-01T00:00:00","2004-02-01T00:00:00","2004-03-01T00:00:00","2004-04-01T00:00:00","2004-05-01T00:00:00","2004-06-01T00:00:00","2004-07-01T00:00:00","2004-08-01T00:00:00","2004-09-01T00:00:00","2004-10-01T00:00:00","2004-11-01T00:00:00","2004-12-01T00:00:00","2005-01-01T00:00:00","2005-02-01T00:00:00","2005-03-01T00:00:00","2005-04-01T00:00:00","2005-05-01T00:00:00","2005-06-01T00:00:00","2005-07-01T00:00:00","2005-08-01T00:00:00","2005-09-01T00:00:00","2005-10-01T00:00:00","2005-11-01T00:00:00","2005-12-01T00:00:00","2006-01-01T00:00:00","2006-02-01T00:00:00","2006-03-01T00:00:00","2006-04-01T00:00:00","2006-05-01T00:00:00","2006-06-01T00:00:00","2006-07-01T00:00:00","2006-08-01T00:00:00","2006-09-01T00:00:00","2006-10-01T00:00:00","2006-11-01T00:00:00","2006-12-01T00:00:00","2007-01-01T00:00:00","2007-02-01T00:00:00","2007-03-01T00:00:00","2007-04-01T00:00:00","2007-05-01T00:00:00","2007-06-01T00:00:00","2007-07-01T00:00:00","2007-08-01T00:00:00","2007-09-01T00:00:00","2007-10-01T00:00:00","2007-11-01T00:00:00","2007 ...

# %%
# Create dataset cuts
salaries_london = df_1[df_1['borough_flag'] == 1]
salaries_england = df_1[df_1['area'] == 'england']
salaries_north_east = df_1[df_1['area'] == 'north east']

# Calcualte mean prices for the different cuts of data
london_mean_salaries = salaries_london.groupby('date')['mean_salary'].mean()
england_mean_salaries = salaries_england.groupby('date')['mean_salary'].mean()
north_east_mean_salaries = salaries_north_east.groupby('date')['mean_salary'].mean()

# Create a new figure
fig = go.Figure()

fig.add_trace(go.Scatter(x=london_mean_salaries.index, 
                         y=london_mean_salaries.values,
                         mode='lines',
                         name='London Mean Salary',
                        ))

fig.add_trace(go.Scatter(x=england_mean_salaries.index, 
                         y=england_mean_salaries.values,
                         mode='lines',
                         name='England Mean Salary',
                        ))

fig.add_trace(go.Scatter(x=north_east_mean_salaries.index, 
                         y=north_east_mean_salaries.values,
                         mode='lines',
                         name='North East Mean Salary',
                        ))


fig.update_layout(
    template='gridon',
    title='Mean Annual Salaries',
    xaxis_title='Year',
    yaxis_title='Salary (£)',
    xaxis_showgrid=False,
    yaxis_showgrid=False,
    legend=dict(y=-.2, orientation='h'),
    shapes=[
        dict(
            type="line",
            x0='2016-06-01',
            x1='2016-06-01',
            y0=0,
            y1=london_mean_salaries.values.max()*1.2,
            line=dict(
            color="LightSalmon",
            dash="dashdot"
            )
        ),
        dict(
            type="rect",
            x0="2007-12-01",
            y0=0,
            x1="2009-06-01",
            y1=london_mean_salaries.values.max()*1.2,
            fillcolor="LightSalmon",
            opacity=0.5,
            layer="below",
            line_width=0,
        ),
        dict(
            type="rect",
            x0="2001-03-01",
            y0=0,
            x1="2001-11-01",
            y1=london_mean_salaries.values.max()*1.2,
            fillcolor="LightSalmon",
            opacity=0.5,
            layer="below",
            line_width=0,
        )
    ],
    annotations=[
            dict(text="The Great Recession", x='2007-12-01', y=london_mean_salaries.values.max()*1.2),
            dict(text="Brexit Vote", x='2016-06-01', y=london_mean_salaries.values.max()*1.2),
            dict(text="Dot-Com Bubble Recession", x='2001-03-01', y=london_mean_salaries.values.max()*1.2)
    ]
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="246fbfc2-4f5f-4bc8-86a5-1256da9cbd0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("246fbfc2-4f5f-4bc8-86a5-1256da9cbd0c")) {                    Plotly.newPlot(                        "246fbfc2-4f5f-4bc8-86a5-1256da9cbd0c",                        [{"mode":"lines","name":"London Mean Salary","x":["1999-12-01T00:00:00","2000-12-01T00:00:00","2001-12-01T00:00:00","2002-12-01T00:00:00","2003-12-01T00:00:00","2004-12-01T00:00:00","2005-12-01T00:00:00","2006-12-01T00:00:00","2007-12-01T00:00:00","2008-12-01T00:00:00","2009-12-01T00:00:00","2010-12-01T00:00:00","2011-12-01T00:00:00","2012-12-01T00:00:00","2013-12-01T00:00:00","2014-12-01T00:00:00","2015-12-01T00:00:00","2016-12-01T00:00:00","2017-12-01T00:00:00","2018-12-01T00:00:00","2019-12-01T00:00:00"],"y":[26053.545454545456,27827.225806451614,29799.9375,30649.151515151516,31986.333333333332,33177.606060606064,34585.181818181816,35998.71875,37421.63636363636,38875.48484848485,39094.93939393939,39103.181818181816,40137.93939393939,39372.78787878788,39353.545454545456,39145.121212121216,38988.878787878784,39856.78125,41087.93939393939,42062.28125,43027.3125],"type":"scatter"},{"mode":"lines","name":"England Mean Salary","x":["1999-12-01T00:00:00","2000-12-01T00:00:00","2001-12-01T00:00:00","2002-12-01T00:00:00","2003-12-01T00:00:00","2004-12-01T00:00:00","2005-12-01T00:00:00","2006-12-01T00:00:00","2007-12-01T00:00:00","2008-12-01T00:00:00","2009-12-01T00:00:00","2010-12-01T00:00:00","2011-12-01T00:00:00","2012-12-01T00:00:00","2013-12-01T00:00:00","2014-12-01T00:00:00","2015-12-01T00:00:00","2016-12-01T00:00:00","2017-12-01T00:00:00","2018-12-01T00:00:00","2019-12-01T00:00:00"],"y":[21561.0,23319.0,24505.0,25542.0,26462.0,27736.0,28928.0,29836.0,30802.0,32358.0,32680.0,33014.0,33514.0,33529.0,33967.0,34214.0,34231.0,35053.0,36076.0,37313.0,38206.0],"type":"scatter"},{"mode":"lines","name":"North East Mean Salary","x":["1999-12-01T00:00:00","2000-12-01T00:00:00","2001-12-01T00:00:00","2002-12-01T00:00:00","2003-12-01T00:00:00","2004-12-01T00:00:00","2005-12-01T00:00:00","2006-12-01T00:00:00","2007-12-01T00:00:00","2008-12-01T00:00:00","2009-12-01T00:00:00","2010-12-01T00:00:00","2011-12-01T00:00:00","2012-12-01T00:00:00","2013-12-01T00:00:00","2014-12-01T00:00:00","2015-12-01T00:00:00","2016-12-01T00:00:00","2017-12-01T00:00:00","2018-12-01T00:00:00","2019-12-01T00:00:00"],"y":[18351.0,19560.0,20103.0,20798.0,21359.0,22377.0,23557.0,24178.0,24299.0,25601.0,26670.0,27405.0,27712.0,27977.0,28460.0,28957.0,29989.0,29574.0,30415.0,31093.0,31852.0],"type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"title":{"text":"Year"},"showgrid":false},"yaxis":{"title":{"text":"Salary (\u00a3)"},"showgrid":false},"legend":{"y":-0.2,"orientation":"h"},"title":{"text":"Mean Annual Salaries"},"shapes":[{"line":{"color":"LightSalmon","dash":"dashdot"},"type":"line","x0":"2016-06-01","x1":"2016-06-01","y0":0,"y1":51632.775},{"fillcolor":"LightSalmon","layer":"below","opacity":0.5,"type":"rect","x0":"2007-12-01","x1":"2009-06-01","y0":0,"y1":51632.775,"line":{"width":0}},{"fillcolor":"LightSalmon","layer":"below","opacity":0.5,"type":"rect","x0":"2001-03-01","x1":"2001-11-01","y0":0,"y1":51632.775,"line":{"width":0}}],"annotations":[{"text":"The Great Recession","x":"2007-12-01","y":51632.775},{"text":"Brexit Vote","x":"2016-06-01","y":51632.775},{"text":"Dot-Com Bubble Recession","x":"2001-03-01","y":51632.775}]},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('246fbfc2-4f5f-4bc8-86a5-1256da9cbd0c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
